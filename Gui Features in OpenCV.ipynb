# %% [markdown]
# # [Getting Started with Images](https://docs.opencv.org/3.1.0/dc/d2e/tutorial_py_image_display.html)

# %% [markdown]
# ## Read & dispaly an image

# %% [markdown]
# cv2.IMREAD_COLOR : Loads a color image. Any transparency of image will be neglected. It is the default flag.
#
# cv2.IMREAD_GRAYSCALE : Loads image in grayscale mode
#
# cv2.IMREAD_UNCHANGED : Loads image as such including alpha channel

# %%
import cv2

# %%
cv2.IMREAD_COLOR
# Out:
# 1

# %%
cv2.IMREAD_GRAYSCALE
# Out:
# 0

# %%
cv2.IMREAD_UNCHANGED
# Out:
# -1

# %%
src = cv2.imread('../../data/book03.jpg',cv2.IMREAD_GRAYSCALE)
cv2.imshow('src',src)
k=cv2.waitKey(0)
cv2.destroyAllWindows()
k
# Out:
# 115

# %% [markdown]
# ### 实验了一下waitKey的返回值：
# ESC == 27
# Space == 32
# s == 115
# 就是ASCII码嘛-。-

# %%
ord('s')
# Out:
# 115

# %%
help(ord)
# Out:
# Help on built-in function ord in module builtins:
#
# ord(c, /)
#     Return the Unicode code point for a one-character string.

# %%
ord('a')
# Out:
# 97

# %% [markdown]
# ### warning
#
# If you are using a 64-bit machine, you will have to modify k = cv2.waitKey(0) line as follows : k = cv2.waitKey(0) & 0xFF
#     <没有好像也没关系？>

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(src,cmap='gray',interpolation='bicubic')
plt.show()

# %% [markdown]
# # [Mouse as a Paint-Brush](https://docs.opencv.org/3.1.0/db/d5b/tutorial_py_mouse_handling.html)

# %%
events = [i for i in dir(cv2) if 'EVENT' in i]
print(events)
# Out:
# ['EVENT_FLAG_ALTKEY', 'EVENT_FLAG_CTRLKEY', 'EVENT_FLAG_LBUTTON', 'EVENT_FLAG_MBUTTON', 'EVENT_FLAG_RBUTTON', 'EVENT_FLAG_SHIFTKEY', 'EVENT_LBUTTONDBLCLK', 'EVENT_LBUTTONDOWN', 'EVENT_LBUTTONUP', 'EVENT_MBUTTONDBLCLK', 'EVENT_MBUTTONDOWN', 'EVENT_MBUTTONUP', 'EVENT_MOUSEHWHEEL', 'EVENT_MOUSEMOVE', 'EVENT_MOUSEWHEEL', 'EVENT_RBUTTONDBLCLK', 'EVENT_RBUTTONDOWN', 'EVENT_RBUTTONUP']
